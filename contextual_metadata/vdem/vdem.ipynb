# %%
install.packages("IRkernel")
IRkernel::installspec(user = TRUE)
# Out:
# The downloaded binary packages are in
# 	/var/folders/7f/y8hpt0cj18sd4rmkbt7rq_bw0000gn/T//Rtmp79Ozgf/downloaded_packages

# %%
# install.packages("cli")
# install.packages("devtools")

devtools::install_github("vdeminstitute/vdemdata")

library(vdemdata)
library(dplyr)
# Out:
# The downloaded binary packages are in
# 	/var/folders/7f/y8hpt0cj18sd4rmkbt7rq_bw0000gn/T//RtmpE9ArsS/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/7f/y8hpt0cj18sd4rmkbt7rq_bw0000gn/T//RtmpE9ArsS/downloaded_packages
# Using GitHub PAT from the git credential store.
#
# Downloading GitHub repo vdeminstitute/vdemdata@HEAD
# lifecycle (1.0.4  -> 1.0.5 ) [CRAN]
# cpp11     (0.5.1  -> 0.5.3 ) [CRAN]
# vctrs     (0.6.5  -> 0.7.1 ) [CRAN]
# utf8      (1.2.4  -> 1.2.6 ) [CRAN]
# pillar    (1.10.1 -> 1.11.1) [CRAN]
# magrittr  (2.0.3  -> 2.0.4 ) [CRAN]
# stringi   (1.8.4  -> 1.8.7 ) [CRAN]
# tibble    (3.2.1  -> 3.3.1 ) [CRAN]
# generics  (0.1.3  -> 0.1.4 ) [CRAN]
# scales    (1.3.0  -> 1.4.0 ) [CRAN]
# S7        (NA     -> 0.2.1 ) [CRAN]
# isoband   (0.2.7  -> 0.3.0 ) [CRAN]
# stringr   (1.5.1  -> 1.6.0 ) [CRAN]
# purrr     (1.0.4  -> 1.2.1 ) [CRAN]
# ggplot2   (3.5.1  -> 4.0.1 ) [CRAN]
# tidyr     (1.3.1  -> 1.3.2 ) [CRAN]
# Installing 16 packages: lifecycle, cpp11, vctrs, utf8, pillar, magrittr, stringi, tibble, generics, scales, S7, isoband, stringr, purrr, ggplot2, tidyr
# The downloaded binary packages are in
# 	/var/folders/7f/y8hpt0cj18sd4rmkbt7rq_bw0000gn/T//RtmpE9ArsS/downloaded_packages
# -- R CMD build -----------------------------------------------------------------
# * checking for file '/private/var/folders/7f/y8hpt0cj18sd4rmkbt7rq_bw0000gn/T/RtmpE9ArsS/remotes16dc1650a9459/vdeminstitute-vdemdata-c783696/DESCRIPTION' ... OK
# * preparing 'vdemdata':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building 'vdemdata_15.0.tar.gz'
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
colnames(vdem)
# Out:
#    [1] "country_name"                    "country_text_id"
#    [3] "country_id"                      "year"
#    [5] "historical_date"                 "project"
#    [7] "historical"                      "histname"
#    [9] "codingstart"                     "codingend"
#   [11] "codingstart_contemp"             "codingend_contemp"
#   [13] "codingstart_hist"                "codingend_hist"
#   [15] "gapstart1"                       "gapstart2"
#   [17] "gapstart3"                       "gapend1"
#   [19] "gapend2"                         "gapend3"
#   [21] "gap_index"                       "COWcode"
#   [23] "v2x_polyarchy"                   "v2x_polyarchy_codelow"
#   [25] "v2x_polyarchy_codehigh"          "v2x_polyarchy_sd"
#   [27] "v2x_libdem"                      "v2x_libdem_codelow"
#   [29] "v2x_libdem_codehigh"             "v2x_libdem_sd"
#   [31] "v2x_partipdem"                   "v2x_partipdem_codelow"
#   [33] "v2x_partipdem_codehigh"          "v2x_partipdem_sd"
#   [35] "v2x_delibdem"                    "v2x_delibdem_codelow"
#   [37] "v2x_delibdem_codehigh"           "v2x_delibdem_sd"
#   [39] "v2x_egaldem"                     "v2x_egaldem_codelow"
#   [41] "v2x_egaldem_codehigh"            "v2x_egaldem_sd"
#   [43] "v2x_api"                         "v2x_api_codelow"
#   [45] "v2x_api_codehigh"                "v2x_api_sd"
#   [47] "v2x_mpi"                         "v2x_mpi_codelow"
#   [49] "v2x_mpi_codehigh"                "v2x_mpi_sd"
#   [51] "v2x_freexp_altinf"               "v2x_freexp_altinf_codelow"
#   [53] "v2x_freexp_altinf_codehigh"      "v2x_freexp_altinf_sd"
#   [55] "v2x_frassoc_thick"               "v2x_frassoc_thick_codelow"
#   [57] "v2x_frassoc_thick_codehigh"      "v2x_frassoc_thick_sd"
#   [59] "v2x_suffr"                       "v2xel_frefair"
#   [61] "v2xel_frefair_codelow"           "v2xel_frefair_codehigh"
#   [63] "v2xel_frefair_sd"                "v2x_elecoff"
#   [65] "v2x_liberal"                     "v2x_liberal_codelow"
#   [67] "v2x_liberal_codehigh"            "v2x_liberal_sd"
#   [69] "v2xcl_rol"                       "v2xcl_rol_codelow"
#   [71] "v2xcl_rol_codehigh"              "v2xcl_rol_sd"
#   [73] "v2x_jucon"                       "v2x_jucon_codelow"
#   [75] "v2x_jucon_codehigh"              "v2x_jucon_sd"
#   [77] "v2xlg_legcon"                    "v2xlg_legcon_codelow"
#   [79] "v2xlg_legcon_codehigh"           "v2xlg_legcon_sd"
#   [81] "v2x_partip"                      "v2x_partip_codelow"
#   [83] "v2x_partip_codehigh"             "v2x_partip_sd"
#   [85] "v2x_cspart"                      "v2x_cspart_codelow"
#   [87] "v2x_cspart_codehigh"             "v2x_cspart_sd"
#   [89] "v2xdd_dd"                        "v2xel_locelec"
#   [91] "v2xel_locelec_codelow"           "v2xel_locelec_codehigh"
#   [93] "v2xel_locelec_sd"                "v2xel_regelec"
#   [95] "v2xel_regelec_codelow"           "v2xel_regelec_codehigh"
#   [97] "v2xel_regelec_sd"                "v2xdl_delib"
#   [99] "v2xdl_delib_codelow"             "v2xdl_delib_codehigh"
#  [101] "v2xdl_delib_sd"                  "v2x_egal"
#  [103] "v2x_egal_codelow"                "v2x_egal_codehigh"
#  [105] "v2x_egal_sd"                     "v2xeg_eqprotec"
#  [107] "v2xeg_eqprotec_codelow"          "v2xeg_eqprotec_codehigh"
#  [109] "v2xeg_eqprotec_sd"               "v2xeg_eqaccess"
#  [111] "v2xeg_eqaccess_codelow"          "v2xeg_eqaccess_codehigh"
#  [113] "v2xeg_eqaccess_sd"               "v2xeg_eqdr"
#  [115] "v2xeg_eqdr_codelow"              "v2xeg_eqdr_codehigh"
#  [117] "v2xeg_eqdr_sd"                   "v2eltype_0"
#  [119] "v2eltype_1"                      "v2eltype_2"
#  [121] "v2eltype_3"                      "v2eltype_4"
#  [123] "v2eltype_5"                      "v2eltype_6"
#  [125] "v2eltype_7"                      "v2eltype_8"
#  [127] "v2eltype_9"                      "v2elcomvot"
#  [129] "v2elfemrst"                      "v2elage"
#  [131] "v2elgvsuflvl"                    "v2elsuffrage"
#  [133] "v2elwestmon"                     "v2asuffrage"
#  [135] "v2fsuffrage"                     "v2msuffrage"
#  [137] "v2eldonate"                      "v2eldonate_codelow"
#  [139] "v2eldonate_codehigh"             "v2eldonate_sd"
#  [141] "v2eldonate_osp"                  "v2eldonate_osp_codelow"
#  [143] "v2eldonate_osp_codehigh"         "v2eldonate_osp_sd"
#  [145] "v2eldonate_ord"                  "v2eldonate_ord_codelow"
#  [147] "v2eldonate_ord_codehigh"         "v2eldonate_mean"
#  [149] "v2eldonate_nr"                   "v2elpubfin"
#  [151] "v2elpubfin_codelow"              "v2elpubfin_codehigh"
#  [153] "v2elpubfin_sd"                   "v2elpubfin_osp"
#  [155] "v2elpubfin_osp_codelow"          "v2elpubfin_osp_codehigh"
#  [157] "v2elpubfin_osp_sd"               "v2elpubfin_ord"
#  [159] "v2elpubfin_ord_codelow"          "v2elpubfin_ord_codehigh"
#  [161] "v2elpubfin_mean"                 "v2elpubfin_nr"
#  [163] "v2elembaut"                      "v2elembaut_codelow"
#  [165] "v2elembaut_codehigh"             "v2elembaut_sd"
#  [167] "v2elembaut_osp"                  "v2elembaut_osp_codelow"
#  [169] "v2elembaut_osp_codehigh"         "v2elembaut_osp_sd"
#  [171] "v2elembaut_ord"                  "v2elembaut_ord_codelow"
#  [173] "v2elembaut_ord_codehigh"         "v2elembaut_mean"
#  [175] "v2elembaut_nr"                   "v2elembcap"
#  [177] "v2elembcap_codelow"              "v2elembcap_codehigh"
#  [179] "v2elembcap_sd"                   "v2elembcap_osp"
#  [181] "v2elembcap_osp_codelow"          "v2elembcap_osp_codehigh"
#  [183] "v2elembcap_osp_sd"               "v2elembcap_ord"
#  [185] "v2elembcap_ord_codelow"          "v2elembcap_ord_codehigh"
#  [187] "v2elembcap_mean"                 "v2elembcap_nr"
#  [189] "v2elmulpar"                      "v2elmulpar_codelow"
#  [191] "v2elmulpar_codehigh"             "v2elmulpar_sd"
#  [193] "v2elmulpar_osp"                  "v2elmulpar_osp_codelow"
#  [195] "v2elmulpar_osp_codehigh"         "v2elmulpar_osp_sd"
#  [197] "v2elmulpar_ord"                  "v2elmulpar_ord_codelow"
#  [199] "v2elmulpar_ord_codehigh"         "v2elmulpar_mean"
#  [201] "v2elmulpar_nr"                   "v2elrgstry"
#  [203] "v2elrgstry_codelow"              "v2elrgstry_codehigh"
#  [205] "v2elrgstry_sd"                   "v2elrgstry_osp"
#  [207] "v2elrgstry_osp_codelow"          "v2elrgstry_osp_codehigh"
#  [209] "v2elrgstry_osp_sd"               "v2elrgstry_ord"
#  [211] "v2elrgstry_ord_codelow"          "v2elrgstry_ord_codehigh"
#  [213] "v2elrgstry_mean"                 "v2elrgstry_nr"
#  [215] "v2elvotbuy"                      "v2elvotbuy_codelow"
#  [217] "v2elvotbuy_codehigh"             "v2elvotbuy_sd"
#  [219] "v2elvotbuy_osp"                  "v2elvotbuy_osp_codelow"
#  [221] "v2elvotbuy_osp_codehigh"         "v2elvotbuy_osp_sd"
#  [223] "v2elvotbuy_ord"                  "v2elvotbuy_ord_codelow"
#  [225] "v2elvotbuy_ord_codehigh"         "v2elvotbuy_mean"
#  [227] "v2elvotbuy_nr"                   "v2elirreg"
#  [229] "v2elirreg_codelow"               "v2elirreg_codehigh"
#  [231] "v2elirreg_sd"                    "v2elirreg_osp"
#  [233] "v2elirreg_osp_codelow"           "v2elirreg_osp_codehigh"
#  [235] "v2elirreg_osp_sd"                "v2elirreg_ord"
#  [237] "v2elirreg_ord_codelow"           "v2elirreg_ord_codehigh"
#  [239] "v2elirreg_mean"                  "v2elirreg_nr"
#  [241] "v2elintim"                       "v2elintim_codelow"
#  [243] "v2elintim_codehigh"              "v2elintim_sd"
#  [245] "v2elintim_osp"                   "v2elintim_osp_codelow"
#  [247] "v2elintim_osp_codehigh"          "v2elintim_osp_sd"
#  [249] "v2elintim_ord"                   "v2elintim_ord_codelow"
#  [251] "v2elintim_ord_codehigh"          "v2elintim_mean"
#  [253] "v2elintim_nr"                    "v2elpeace"
#  [255] "v2elpeace_codelow"               "v2elpeace_codehigh"
#  [257] "v2elpeace_sd"                    "v2elpeace_osp"
#  [259] "v2elpeace_osp_codelow"           "v2elpeace_osp_codehigh"
#  [261] "v2elpeace_osp_sd"                "v2elpeace_ord"
#  [263] "v2elpeace_ord_codelow"           "v2elpeace_ord_codehigh"
#  [265] "v2elpeace_mean"                  "v2elpeace_nr"
#  [267] "v2elboycot"                      "v2elboycot_codelow"
#  [269] "v2elboycot_codehigh"             "v2elboycot_sd"
#  [271] "v2elboycot_osp"                  "v2elboycot_osp_codelow"
#  [273] "v2elboycot_osp_codehigh"         "v2elboycot_osp_sd"
#  [275] "v2elboycot_ord"                  "v2elboycot_ord_codelow"
#  [277] "v2elboycot_ord_codehigh"         "v2elboycot_mean"
#  [279] "v2elboycot_nr"                   "v2elfrcamp"
#  [281] "v2elfrcamp_codelow"              "v2elfrcamp_codehigh"
#  [283] "v2elfrcamp_sd"                   "v2elfrcamp_osp"
#  [285] "v2elfrcamp_osp_codelow"          "v2elfrcamp_osp_codehigh"
#  [287] "v2elfrcamp_osp_sd"               "v2elfrcamp_ord"
#  [289] "v2elfrcamp_ord_codelow"          "v2elfrcamp_ord_codehigh"
#  [291] "v2elfrcamp_mean"                 "v2elfrcamp_nr"
#  [293] "v2elpdcamp"                      "v2elpdcamp_codelow"
#  [295] "v2elpdcamp_codehigh"             "v2elpdcamp_sd"
#  [297] "v2elpdcamp_osp"                  "v2elpdcamp_osp_codelow"
#  [299] "v2elpdcamp_osp_codehigh"         "v2elpdcamp_osp_sd"
#  [301] "v2elpdcamp_ord"                  "v2elpdcamp_ord_codelow"
#  [303] "v2elpdcamp_ord_codehigh"         "v2elpdcamp_mean"
#  [305] "v2elpdcamp_nr"                   "v2elpaidig"
#  [307] "v2elpaidig_codelow"              "v2elpaidig_codehigh"
#  [309] "v2elpaidig_sd"                   "v2elpaidig_osp"
#  [311] "v2elpaidig_osp_codelow"          "v2elpaidig_osp_codehigh"
#  [313] "v2elpaidig_osp_sd"               "v2elpaidig_ord"
#  [315] "v2elpaidig_ord_codelow"          "v2elpaidig_ord_codehigh"
#  [317] "v2elpaidig_mean"                 "v2elpaidig_nr"
#  [319] "v2elfrfair"                      "v2elfrfair_codelow"
#  [321] "v2elfrfair_codehigh"             "v2elfrfair_sd"
#  [323] "v2elfrfair_osp"                  "v2elfrfair_osp_codelow"
#  [325] "v2elfrfair_osp_codehigh"         "v2elfrfair_osp_sd"
#  [327] "v2elfrfair_ord"                  "v2elfrfair_ord_codelow"
#  [329] "v2elfrfair_ord_codehigh"         "v2elfrfair_mean"
#  [331] "v2elfrfair_nr"                   "v2elrstrct"
#  [333] "v2eldommon"                      "v2elintmon"
#  [335] "v2elmonden"                      "v2elmonref"
#  [337] "v2elaccept"                      "v2elaccept_codelow"
#  [339] "v2elaccept_codehigh"             "v2elaccept_sd"
#  [341] "v2elaccept_osp"                  "v2elaccept_osp_codelow"
#  [343] "v2elaccept_osp_codehigh"         "v2elaccept_osp_sd"
#  [345] "v2elaccept_ord"                  "v2elaccept_ord_codelow"
#  [347] "v2elaccept_ord_codehigh"         "v2elaccept_mean"
#  [349] "v2elaccept_nr"                   "v2elasmoff"
#  [351] "v2elasmoff_codelow"              "v2elasmoff_codehigh"
#  [353] "v2elasmoff_sd"                   "v2elasmoff_osp"
#  [355] "v2elasmoff_osp_codelow"          "v2elasmoff_osp_codehigh"
#  [357] "v2elasmoff_osp_sd"               "v2elasmoff_ord"
#  [359] "v2elasmoff_ord_codelow"          "v2elasmoff_ord_codehigh"
#  [361] "v2elasmoff_mean"                 "v2elasmoff_nr"
#  [363] "v2elvaptrn"                      "v2eltrnout"
#  [365] "v2lpname"                        "v2slpname"
#  [367] "v2tlpname"                       "v2eltvrexo"
#  [369] "v2elvotlrg"                      "v2elvotsml"
#  [371] "v2elturnhog"                     "v2elturnhos"
#  [373] "v2elrsthos"                      "v2elrsthog"
#  [375] "v2elprescons"                    "v2elprescumul"
#  [377] "v2elthresh"                      "v2eltvrig"
#  [379] "v2ellostsl"                      "v2ellostss"
#  [381] "v2ellovtlg"                      "v2ellovtsm"
#  [383] "v2ellostlg"                      "v2elloseat"
#  [385] "v2ellostsm"                      "v2elloelsy"
#  [387] "v2ellocons"                      "v2ellocumul"
#  [389] "v2elparlel"                      "v2elloeldm"
#  [391] "v2ellovttm"                      "v2ellosttm"
#  [393] "v2ellostts"                      "v2ellobaseat"
#  [395] "v2ellobadis"                     "v2elloupdis"
#  [397] "v2elloreseat"                    "v2ellodiseff"
#  [399] "v2elreggov"                      "v2elregnam"
#  [401] "v2elsrgel"                       "v2elrgpwr"
#  [403] "v2elrgpwr_codelow"               "v2elrgpwr_codehigh"
#  [405] "v2elrgpwr_sd"                    "v2elrgpwr_osp"
#  [407] "v2elrgpwr_osp_codelow"           "v2elrgpwr_osp_codehigh"
#  [409] "v2elrgpwr_osp_sd"                "v2elrgpwr_ord"
#  [411] "v2elrgpwr_ord_codelow"           "v2elrgpwr_ord_codehigh"
#  [413] "v2elrgpwr_mean"                  "v2elrgpwr_nr"
#  [415] "v2ellocgov"                      "v2ellocnam"
#  [417] "v2ellocelc"                      "v2ellocpwr"
#  [419] "v2ellocpwr_codelow"              "v2ellocpwr_codehigh"
#  [421] "v2ellocpwr_sd"                   "v2ellocpwr_osp"
#  [423] "v2ellocpwr_osp_codelow"          "v2ellocpwr_osp_codehigh"
#  [425] "v2ellocpwr_osp_sd"               "v2ellocpwr_ord"
#  [427] "v2ellocpwr_ord_codelow"          "v2ellocpwr_ord_codehigh"
#  [429] "v2ellocpwr_mean"                 "v2ellocpwr_nr"
#  [431] "v2elffelr"                       "v2elffelr_codelow"
#  [433] "v2elffelr_codehigh"              "v2elffelr_sd"
#  [435] "v2elffelr_osp"                   "v2elffelr_osp_codelow"
#  [437] "v2elffelr_osp_codehigh"          "v2elffelr_osp_sd"
#  [439] "v2elffelr_ord"                   "v2elffelr_ord_codelow"
#  [441] "v2elffelr_ord_codehigh"          "v2elffelr_mean"
#  [443] "v2elffelr_nr"                    "v2elffelrbin"
#  [445] "v2elffelrbin_codelow"            "v2elffelrbin_codehigh"
#  [447] "v2elffelrbin_sd"                 "v2elffelrbin_osp"
#  [449] "v2elffelrbin_osp_codelow"        "v2elffelrbin_osp_codehigh"
#  [451] "v2elffelrbin_osp_sd"             "v2elffelrbin_ord"
#  [453] "v2elffelrbin_ord_codelow"        "v2elffelrbin_ord_codehigh"
#  [455] "v2elffelrbin_mean"               "v2elffelrbin_nr"
#  [457] "v2elsnlsff"                      "v2elsnlsff_codelow"
#  [459] "v2elsnlsff_codehigh"             "v2elsnlsff_sd"
#  [461] "v2elsnlsff_osp"                  "v2elsnlsff_osp_codelow"
#  [463] "v2elsnlsff_osp_codehigh"         "v2elsnlsff_osp_sd"
#  [465] "v2elsnlsff_ord"                  "v2elsnlsff_ord_codelow"
#  [467] "v2elsnlsff_ord_codehigh"         "v2elsnlsff_mean"
#  [469] "v2elsnlsff_nr"                   "v2elsnlfc_0"
#  [471] "v2elsnlfc_1"                     "v2elsnlfc_2"
#  [473] "v2elsnlfc_3"                     "v2elsnlfc_4"
#  [475] "v2elsnlfc_5"                     "v2elsnlfc_6"
#  [477] "v2elsnlfc_7"                     "v2elsnlfc_8"
#  [479] "v2elsnlfc_9"                     "v2elsnlfc_10"
#  [481] "v2elsnlfc_11"                    "v2elsnlfc_12"
#  [483] "v2elsnlfc_13"                    "v2elsnlfc_14"
#  [485] "v2elsnlfc_15"                    "v2elsnlfc_16"
#  [487] "v2elsnlfc_17"                    "v2elsnlfc_18"
#  [489] "v2elsnlfc_19"                    "v2elsnlfc_20"
#  [491] "v2elsnlfc_21"                    "v2elsnlfc_nr"
#  [493] "v2elsnmrfc_0"                    "v2elsnmrfc_1"
#  [495] "v2elsnmrfc_2"                    "v2elsnmrfc_3"
#  [497] "v2elsnmrfc_4"                    "v2elsnmrfc_5"
#  [499] "v2elsnmrfc_6"                    "v2elsnmrfc_7"
#  [501] "v2elsnmrfc_8"                    "v2elsnmrfc_9"
#  [503] "v2elsnmrfc_10"                   "v2elsnmrfc_11"
#  [505] "v2elsnmrfc_12"                   "v2elsnmrfc_13"
#  [507] "v2elsnmrfc_14"                   "v2elsnmrfc_15"
#  [509] "v2elsnmrfc_16"                   "v2elsnmrfc_17"
#  [511] "v2elsnmrfc_18"                   "v2elsnmrfc_19"
#  [513] "v2elsnmrfc_20"                   "v2elsnmrfc_21"
#  [515] "v2elsnmrfc_nr"                   "v2psbars"
#  [517] "v2psbars_codelow"                "v2psbars_codehigh"
#  [519] "v2psbars_sd"                     "v2psbars_osp"
#  [521] "v2psbars_osp_codelow"            "v2psbars_osp_codehigh"
#  [523] "v2psbars_osp_sd"                 "v2psbars_ord"
#  [525] "v2psbars_ord_codelow"            "v2psbars_ord_codehigh"
#  [527] "v2psbars_mean"                   "v2psbars_nr"
#  [529] "v2psparban"                      "v2psparban_codelow"
#  [531] "v2psparban_codehigh"             "v2psparban_sd"
#  [533] "v2psparban_osp"                  "v2psparban_osp_codelow"
#  [535] "v2psparban_osp_codehigh"         "v2psparban_osp_sd"
#  [537] "v2psparban_ord"                  "v2psparban_ord_codelow"
#  [539] "v2psparban_ord_codehigh"         "v2psparban_mean"
#  [541] "v2psparban_nr"                   "v2psoppaut"
#  [543] "v2psoppaut_codelow"              "v2psoppaut_codehigh"
#  [545] "v2psoppaut_sd"                   "v2psoppaut_osp"
#  [547] "v2psoppaut_osp_codelow"          "v2psoppaut_osp_codehigh"
#  [549] "v2psoppaut_osp_sd"               "v2psoppaut_ord"
#  [551] "v2psoppaut_ord_codelow"          "v2psoppaut_ord_codehigh"
#  [553] "v2psoppaut_mean"                 "v2psoppaut_nr"
#  [555] "v2psorgs"                        "v2psorgs_codelow"
#  [557] "v2psorgs_codehigh"               "v2psorgs_sd"
#  [559] "v2psorgs_osp"                    "v2psorgs_osp_codelow"
#  [561] "v2psorgs_osp_codehigh"           "v2psorgs_osp_sd"
#  [563] "v2psorgs_ord"                    "v2psorgs_ord_codelow"
#  [565] "v2psorgs_ord_codehigh"           "v2psorgs_mean"
#  [567] "v2psorgs_nr"                     "v2psprbrch"
#  [569] "v2psprbrch_codelow"              "v2psprbrch_codehigh"
#  [571] "v2psprbrch_sd"                   "v2psprbrch_osp"
#  [573] "v2psprbrch_osp_codelow"          "v2psprbrch_osp_codehigh"
#  [575] "v2psprbrch_osp_sd"               "v2psprbrch_ord"
#  [577] "v2psprbrch_ord_codelow"          "v2psprbrch_ord_codehigh"
#  [579] "v2psprbrch_mean"                 "v2psprbrch_nr"
#  [581] "v2psprlnks"                      "v2psprlnks_codelow"
#  [583] "v2psprlnks_codehigh"             "v2psprlnks_sd"
#  [585] "v2psprlnks_osp"                  "v2psprlnks_osp_codelow"
#  [587] "v2psprlnks_osp_codehigh"         "v2psprlnks_osp_sd"
#  [589] "v2psprlnks_ord"                  "v2psprlnks_ord_codelow"
#  [591] "v2psprlnks_ord_codehigh"         "v2psprlnks_mean"
#  [593] "v2psprlnks_nr"                   "v2psplats"
#  [595] "v2psplats_codelow"               "v2psplats_codehigh"
#  [597] "v2psplats_sd"                    "v2psplats_osp"
#  [599] "v2psplats_osp_codelow"           "v2psplats_osp_codehigh"
#  [601] "v2psplats_osp_sd"                "v2psplats_ord"
#  [603] "v2psplats_ord_codelow"           "v2psplats_ord_codehigh"
#  [605] "v2psplats_mean"                  "v2psplats_nr"
#  [607] "v2pscnslnl"                      "v2pscnslnl_codelow"
#  [609] "v2pscnslnl_codehigh"             "v2pscnslnl_sd"
#  [611] "v2pscnslnl_osp"                  "v2pscnslnl_osp_codelow"
#  [613] "v2pscnslnl_osp_codehigh"         "v2pscnslnl_osp_sd"
#  [615] "v2pscnslnl_ord"                  "v2pscnslnl_ord_codelow"
#  [617] "v2pscnslnl_ord_codehigh"         "v2pscnslnl_mean"
#  [619] "v2pscnslnl_nr"                   "v2pscohesv"
#  [621] "v2pscohesv_codelow"              "v2pscohesv_codehigh"
#  [623] "v2pscohesv_sd"                   "v2pscohesv_osp"
#  [625] "v2pscohesv_osp_codelow"          "v2pscohesv_osp_codehigh"
#  [627] "v2pscohesv_osp_sd"               "v2pscohesv_ord"
#  [629] "v2pscohesv_ord_codelow"          "v2pscohesv_ord_codehigh"
#  [631] "v2pscohesv_mean"                 "v2pscohesv_nr"
#  [633] "v2pscomprg"                      "v2pscomprg_codelow"
#  [635] "v2pscomprg_codehigh"             "v2pscomprg_sd"
#  [637] "v2pscomprg_osp"                  "v2pscomprg_osp_codelow"
#  [639] "v2pscomprg_osp_codehigh"         "v2pscomprg_osp_sd"
#  [641] "v2pscomprg_ord"                  "v2pscomprg_ord_codelow"
#  [643] "v2pscomprg_ord_codehigh"         "v2pscomprg_mean"
#  [645] "v2pscomprg_nr"                   "v2psnatpar"
#  [647] "v2psnatpar_codelow"              "v2psnatpar_codehigh"
#  [649] "v2psnatpar_sd"                   "v2psnatpar_osp"
#  [651] "v2psnatpar_osp_codelow"          "v2psnatpar_osp_codehigh"
#  [653] "v2psnatpar_osp_sd"               "v2psnatpar_ord"
#  [655] "v2psnatpar_ord_codelow"          "v2psnatpar_ord_codehigh"
#  [657] "v2psnatpar_mean"                 "v2psnatpar_nr"
#  [659] "v2pssunpar"                      "v2pssunpar_codelow"
#  [661] "v2pssunpar_codehigh"             "v2pssunpar_sd"
#  [663] "v2pssunpar_osp"                  "v2pssunpar_osp_codelow"
#  [665] "v2pssunpar_osp_codehigh"         "v2pssunpar_osp_sd"
#  [667] "v2pssunpar_ord"                  "v2pssunpar_ord_codelow"
#  [669] "v2pssunpar_ord_codehigh"         "v2pssunpar_mean"
#  [671] "v2pssunpar_nr"                   "v2psbantar_0"
#  [673] "v2psbantar_1"                    "v2psbantar_2"
#  [675] "v2psbantar_3"                    "v2psbantar_4"
#  [677] "v2psbantar_5"                    "v2psbantar_nr"
#  [679] "v2ddlexci"                       "v2ddsignci"
#  [681] "v2ddsigpci"                      "v2ddsigdci"
#  [683] "v2ddsiglci"                      "v2ddpartci"
#  [685] "v2ddapprci"                      "v2ddadmci"
#  [687] "v2ddspmci"                       "v2ddthreci"
#  [689] "v2ddlexrf"                       "v2ddsignrf"
#  [691] "v2ddsigprf"                      "v2ddsigdrf"
#  [693] "v2ddsiglrf"                      "v2ddpartrf"
#  [695] "v2ddapprrf"                      "v2ddadmrf"
#  [697] "v2ddspmrf"                       "v2ddthrerf"
#  [699] "v2ddlexor"                       "v2ddpartor"
#  [701] "v2ddappor"                       "v2ddadmor"
#  [703] "v2ddspmor"                       "v2ddthreor"
#  [705] "v2ddlexpl"                       "v2ddpartpl"
#  [707] "v2ddapprpl"                      "v2ddadmpl"
#  [709] "v2ddspmpl"                       "v2ddthrepl"
#  [711] "v2ddyrci"                        "v2ddyrrf"
#  [713] "v2ddyror"                        "v2ddyrpl"
#  [715] "v2ddyrall"                       "v2ddcredal"
#  [717] "v2exnamhos"                      "v2extithos"
#  [719] "v2exremhsp"                      "v2exremhsp_codelow"
#  [721] "v2exremhsp_codehigh"             "v2exremhsp_sd"
#  [723] "v2exremhsp_osp"                  "v2exremhsp_osp_codelow"
#  [725] "v2exremhsp_osp_codehigh"         "v2exremhsp_osp_sd"
#  [727] "v2exremhsp_ord"                  "v2exremhsp_ord_codelow"
#  [729] "v2exremhsp_ord_codehigh"         "v2exremhsp_mean"
#  [731] "v2exremhsp_nr"                   "v2exdfdshs"
#  [733] "v2exdfdshs_codelow"              "v2exdfdshs_codehigh"
#  [735] "v2exdfdshs_sd"                   "v2exdfdshs_osp"
#  [737] "v2exdfdshs_osp_codelow"          "v2exdfdshs_osp_codehigh"
#  [739] "v2exdfdshs_osp_sd"               "v2exdfdshs_ord"
#  [741] "v2exdfdshs_ord_codelow"          "v2exdfdshs_ord_codehigh"
#  [743] "v2exdfdshs_mean"                 "v2exdfdshs_nr"
#  [745] "v2exdfcbhs"                      "v2exdfcbhs_codelow"
#  [747] "v2exdfcbhs_codehigh"             "v2exdfcbhs_sd"
#  [749] "v2exdfcbhs_osp"                  "v2exdfcbhs_osp_codelow"
#  [751] "v2exdfcbhs_osp_codehigh"         "v2exdfcbhs_osp_sd"
#  [753] "v2exdfcbhs_ord"                  "v2exdfcbhs_ord_codelow"
#  [755] "v2exdfcbhs_ord_codehigh"         "v2exdfcbhs_mean"
#  [757] "v2exdfcbhs_nr"                   "v2exdfvths"
#  [759] "v2exdfvths_codelow"              "v2exdfvths_codehigh"
#  [761] "v2exdfvths_sd"                   "v2exdfvths_osp"
#  [763] "v2exdfvths_osp_codelow"          "v2exdfvths_osp_codehigh"
#  [765] "v2exdfvths_osp_sd"               "v2exdfvths_ord"
#  [767] "v2exdfvths_ord_codelow"          "v2exdfvths_ord_codehigh"
#  [769] "v2exdfvths_mean"                 "v2exdfvths_nr"
#  [771] "v2exdfdmhs"                      "v2exdfdmhs_codelow"
#  [773] "v2exdfdmhs_codehigh"             "v2exdfdmhs_sd"
#  [775] "v2exdfdmhs_osp"                  "v2exdfdmhs_osp_codelow"
#  [777] "v2exdfdmhs_osp_codehigh"         "v2exdfdmhs_osp_sd"
#  [779] "v2exdfdmhs_ord"                  "v2exdfdmhs_ord_codelow"
#  [781] "v2exdfdmhs_ord_codehigh"         "v2exdfdmhs_mean"
#  [783] "v2exdfdmhs_nr"                   "v2exdfpphs"
#  [785] "v2exdfpphs_codelow"              "v2exdfpphs_codehigh"
#  [787] "v2exdfpphs_sd"                   "v2exdfpphs_osp"
#  [789] "v2exdfpphs_osp_codelow"          "v2exdfpphs_osp_codehigh"
#  [791] "v2exdfpphs_osp_sd"               "v2exdfpphs_ord"
#  [793] "v2exdfpphs_ord_codelow"          "v2exdfpphs_ord_codehigh"
#  [795] "v2exdfpphs_mean"                 "v2exdfpphs_nr"
#  [797] "v2exhoshog"                      "v2exagehos"
#  [799] "v2exaphos"                       "v2ex_elechos"
#  [801] "v2exfemhos"                      "v2exfxtmhs"
#  [803] "v2expathhs"                      "v2exdeathos"
#  [805] "v2exparhos"                      "v2exctlhs_0"
#  [807] "v2exctlhs_1"                     "v2exctlhs_2"
#  [809] "v2exctlhs_3"                     "v2exctlhs_4"
#  [811] "v2exctlhs_5"                     "v2exctlhs_6"
#  [813] "v2exctlhs_7"                     "v2exctlhs_nr"
#  [815] "v2exrmhsol_0"                    "v2exrmhsol_1"
#  [817] "v2exrmhsol_2"                    "v2exrmhsol_3"
#  [819] "v2exrmhsol_4"                    "v2exrmhsol_5"
#  [821] "v2exrmhsol_6"                    "v2exrmhsol_7"
#  [823] "v2exrmhsol_nr"                   "v2exdfcbhs_rec"
#  [825] "v2exdfcbhs_rec_codelow"          "v2exdfcbhs_rec_codehigh"
#  [827] "v2exdfcbhs_rec_sd"               "v2exdfcbhs_rec_osp"
#  [829] "v2exdfcbhs_rec_osp_codelow"      "v2exdfcbhs_rec_osp_codehigh"
#  [831] "v2exdfcbhs_rec_osp_sd"           "v2exdfcbhs_rec_ord"
#  [833] "v2exdfcbhs_rec_ord_codelow"      "v2exdfcbhs_rec_ord_codehigh"
#  [835] "v2exdfcbhs_rec_mean"             "v2exdfcbhs_rec_nr"
#  [837] "v2exnamhog"                      "v2extithog"
#  [839] "v2exremhog"                      "v2exremhog_codelow"
#  [841] "v2exremhog_codehigh"             "v2exremhog_sd"
#  [843] "v2exremhog_osp"                  "v2exremhog_osp_codelow"
#  [845] "v2exremhog_osp_codehigh"         "v2exremhog_osp_sd"
#  [847] "v2exremhog_ord"                  "v2exremhog_ord_codelow"
#  [849] "v2exremhog_ord_codehigh"         "v2exremhog_mean"
#  [851] "v2exremhog_nr"                   "v2exdjdshg"
#  [853] "v2exdjdshg_codelow"              "v2exdjdshg_codehigh"
#  [855] "v2exdjdshg_sd"                   "v2exdjdshg_osp"
#  [857] "v2exdjdshg_osp_codelow"          "v2exdjdshg_osp_codehigh"
#  [859] "v2exdjdshg_osp_sd"               "v2exdjdshg_ord"
#  [861] "v2exdjdshg_ord_codelow"          "v2exdjdshg_ord_codehigh"
#  [863] "v2exdjdshg_mean"                 "v2exdjdshg_nr"
#  [865] "v2exdjcbhg"                      "v2exdjcbhg_codelow"
#  [867] "v2exdjcbhg_codehigh"             "v2exdjcbhg_sd"
#  [869] "v2exdjcbhg_osp"                  "v2exdjcbhg_osp_codelow"
#  [871] "v2exdjcbhg_osp_codehigh"         "v2exdjcbhg_osp_sd"
#  [873] "v2exdjcbhg_ord"                  "v2exdjcbhg_ord_codelow"
#  [875] "v2exdjcbhg_ord_codehigh"         "v2exdjcbhg_mean"
#  [877] "v2exdjcbhg_nr"                   "v2exdfdshg"
#  [879] "v2exdfdshg_codelow"              "v2exdfdshg_codehigh"
#  [881] "v2exdfdshg_sd"                   "v2exdfdshg_osp"
#  [883] "v2exdfdshg_osp_codelow"          "v2exdfdshg_osp_codehigh"
#  [885] "v2exdfdshg_osp_sd"               "v2exdfdshg_ord"
#  [887] "v2exdfdshg_ord_codelow"          "v2exdfdshg_ord_codehigh"
#  [889] "v2exdfdshg_mean"                 "v2exdfdshg_nr"
#  [891] "v2exdfvthg"                      "v2exdfvthg_codelow"
#  [893] "v2exdfvthg_codehigh"             "v2exdfvthg_sd"
#  [895] "v2exdfvthg_osp"                  "v2exdfvthg_osp_codelow"
#  [897] "v2exdfvthg_osp_codehigh"         "v2exdfvthg_osp_sd"
#  [899] "v2exdfvthg_ord"                  "v2exdfvthg_ord_codelow"
#  [901] "v2exdfvthg_ord_codehigh"         "v2exdfvthg_mean"
#  [903] "v2exdfvthg_nr"                   "v2exdfpphg"
#  [905] "v2exdfpphg_codelow"              "v2exdfpphg_codehigh"
#  [907] "v2exdfpphg_sd"                   "v2exdfpphg_osp"
#  [909] "v2exdfpphg_osp_codelow"          "v2exdfpphg_osp_codehigh"
#  [911] "v2exdfpphg_osp_sd"               "v2exdfpphg_ord"
#  [913] "v2exdfpphg_ord_codelow"          "v2exdfpphg_ord_codehigh"
#  [915] "v2exdfpphg_mean"                 "v2exdfpphg_nr"
#  [917] "v2exagehog"                      "v2exaphogp"
#  [919] "v2ex_elechog"                    "v2exfemhog"
#  [921] "v2exfxtmhg"                      "v2ex_hogw"
#  [923] "v2ex_hosconhog"                  "v2expathhg"
#  [925] "v2expothog"                      "v2exdeathog"
#  [927] "v2exctlhg_0"                     "v2exctlhg_1"
#  [929] "v2exctlhg_2"                     "v2exctlhg_3"
#  [931] "v2exctlhg_4"                     "v2exctlhg_5"
#  [933] "v2exctlhg_6"                     "v2exctlhg_7"
#  [935] "v2exctlhg_8"                     "v2exctlhg_nr"
#  [937] "v2exrmhgnp_0"                    "v2exrmhgnp_1"
#  [939] "v2exrmhgnp_2"                    "v2exrmhgnp_3"
#  [941] "v2exrmhgnp_4"                    "v2exrmhgnp_5"
#  [943] "v2exrmhgnp_6"                    "v2exrmhgnp_7"
#  [945] "v2exrmhgnp_8"                    "v2exrmhgnp_nr"
#  [947] "v2exrescon"                      "v2exrescon_codelow"
#  [949] "v2exrescon_codehigh"             "v2exrescon_sd"
#  [951] "v2exrescon_osp"                  "v2exrescon_osp_codelow"
#  [953] "v2exrescon_osp_codehigh"         "v2exrescon_osp_sd"
#  [955] "v2exrescon_ord"                  "v2exrescon_ord_codelow"
#  [957] "v2exrescon_ord_codehigh"         "v2exrescon_mean"
#  [959] "v2exrescon_nr"                   "v2exbribe"
#  [961] "v2exbribe_codelow"               "v2exbribe_codehigh"
#  [963] "v2exbribe_sd"                    "v2exbribe_osp"
#  [965] "v2exbribe_osp_codelow"           "v2exbribe_osp_codehigh"
#  [967] "v2exbribe_osp_sd"                "v2exbribe_ord"
#  [969] "v2exbribe_ord_codelow"           "v2exbribe_ord_codehigh"
#  [971] "v2exbribe_mean"                  "v2exbribe_nr"
#  [973] "v2exembez"                       "v2exembez_codelow"
#  [975] "v2exembez_codehigh"              "v2exembez_sd"
#  [977] "v2exembez_osp"                   "v2exembez_osp_codelow"
#  [979] "v2exembez_osp_codehigh"          "v2exembez_osp_sd"
#  [981] "v2exembez_ord"                   "v2exembez_ord_codelow"
#  [983] "v2exembez_ord_codehigh"          "v2exembez_mean"
#  [985] "v2exembez_nr"                    "v2excrptps"
#  [987] "v2excrptps_codelow"              "v2excrptps_codehigh"
#  [989] "v2excrptps_sd"                   "v2excrptps_osp"
#  [991] "v2excrptps_osp_codelow"          "v2excrptps_osp_codehigh"
#  [993] "v2excrptps_osp_sd"               "v2excrptps_ord"
#  [995] "v2excrptps_ord_codelow"          "v2excrptps_ord_codehigh"
#  [997] "v2excrptps_mean"                 "v2excrptps_nr"
#  [999] "v2exthftps"                      "v2exthftps_codelow"
# [1001] "v2exthftps_codehigh"             "v2exthftps_sd"
# [1003] "v2exthftps_osp"                  "v2exthftps_osp_codelow"
# [1005] "v2exthftps_osp_codehigh"         "v2exthftps_osp_sd"
# [1007] "v2exthftps_ord"                  "v2exthftps_ord_codelow"
# [1009] "v2exthftps_ord_codehigh"         "v2exthftps_mean"
# [1011] "v2exthftps_nr"                   "v2exapup"
# [1013] "v2exapupap"                      "v2reginfo"
# [1015] "v2regendtype"                    "v2regint"
# [1017] "v2regidnr"                       "v2regdur"
# [1019] "v2regimpgroup"                   "v2regimpgroup_nr"
# [1021] "v2regsupgroupssize"              "v2regsupgroupssize_codelow"
# [1023] "v2regsupgroupssize_codehigh"     "v2regsupgroupssize_sd"
# [1025] "v2regsupgroupssize_osp"          "v2regsupgroupssize_osp_codelow"
# [1027] "v2regsupgroupssize_osp_codehigh" "v2regsupgroupssize_osp_sd"
# [1029] "v2regsupgroupssize_ord"          "v2regsupgroupssize_ord_codelow"
# [1031] "v2regsupgroupssize_ord_codehigh" "v2regsupgroupssize_mean"
# [1033] "v2regsupgroupssize_nr"           "v2regsuploc"
# [1035] "v2regsuploc_nr"                  "v2regimpoppgroup"
# [1037] "v2regimpoppgroup_nr"             "v2regoppgroupssize"
# [1039] "v2regoppgroupssize_codelow"      "v2regoppgroupssize_codehigh"
# [1041] "v2regoppgroupssize_sd"           "v2regoppgroupssize_osp"
# [1043] "v2regoppgroupssize_osp_codelow"  "v2regoppgroupssize_osp_codehigh"
# [1045] "v2regoppgroupssize_osp_sd"       "v2regoppgroupssize_ord"
# [1047] "v2regoppgroupssize_ord_codelow"  "v2regoppgroupssize_ord_codehigh"
# [1049] "v2regoppgroupssize_mean"         "v2regoppgroupssize_nr"
# [1051] "v2regopploc"                     "v2regopploc_nr"
# [1053] "v2regproreg"                     "v2regproreg_nr"
# [1055] "v2regantireg"                    "v2regantireg_nr"
# [1057] "v2regpower"                      "v2regpower_nr"
# [1059] "v2regendtypems_0"                "v2regendtypems_1"
# [1061] "v2regendtypems_2"                "v2regendtypems_3"
# [1063] "v2regendtypems_4"                "v2regendtypems_5"
# [1065] "v2regendtypems_6"                "v2regendtypems_7"
# [1067] "v2regendtypems_8"                "v2regendtypems_9"
# [1069] "v2regendtypems_10"               "v2regendtypems_11"
# [1071] "v2regendtypems_12"               "v2regsupgroups_0"
# [1073] "v2regsupgroups_1"                "v2regsupgroups_2"
# [1075] "v2regsupgroups_3"                "v2regsupgroups_4"
# [1077] "v2regsupgroups_5"                "v2regsupgroups_6"
# [1079] "v2regsupgroups_7"                "v2regsupgroups_8"
# [1081] "v2regsupgroups_9"                "v2regsupgroups_10"
# [1083] "v2regsupgroups_11"               "v2regsupgroups_12"
# [1085] "v2regsupgroups_13"               "v2regsupgroups_nr"
# [1087] "v2regendtypems_13"               "v2regoppgroupsact_0"
# [1089] "v2regoppgroupsact_1"             "v2regoppgroupsact_2"
# [1091] "v2regoppgroupsact_3"             "v2regoppgroupsact_4"
# [1093] "v2regoppgroupsact_5"             "v2regoppgroupsact_6"
# [1095] "v2regoppgroupsact_7"             "v2regoppgroupsact_8"
# [1097] "v2regoppgroupsact_9"             "v2regoppgroupsact_10"
# [1099] "v2regoppgroupsact_11"            "v2regoppgroupsact_12"
# [1101] "v2regoppgroupsact_13"            "v2regoppgroupsact_nr"
# [1103] "v2regoppgroups_0"                "v2regoppgroups_1"
# [1105] "v2regoppgroups_2"                "v2regoppgroups_3"
# [1107] "v2regoppgroups_4"                "v2regoppgroups_5"
# [1109] "v2regoppgroups_6"                "v2regoppgroups_7"
# [1111] "v2regoppgroups_8"                "v2regoppgroups_9"
# [1113] "v2regoppgroups_10"               "v2regoppgroups_11"
# [1115] "v2regoppgroups_12"               "v2regoppgroups_13"
# [1117] "v2regoppgroups_nr"               "v2lgbicam"
# [1119] "v2lgdomchm"                      "v2lgdomchm_codelow"
# [1121] "v2lgdomchm_codehigh"             "v2lgdomchm_sd"
# [1123] "v2lgdomchm_osp"                  "v2lgdomchm_osp_codelow"
# [1125] "v2lgdomchm_osp_codehigh"         "v2lgdomchm_osp_sd"
# [1127] "v2lgdomchm_ord"                  "v2lgdomchm_ord_codelow"
# [1129] "v2lgdomchm_ord_codehigh"         "v2lgdomchm_mean"
# [1131] "v2lgdomchm_nr"                   "v2lgqstexp"
# [1133] "v2lgqstexp_codelow"              "v2lgqstexp_codehigh"
# [1135] "v2lgqstexp_sd"                   "v2lgqstexp_osp"
# [1137] "v2lgqstexp_osp_codelow"          "v2lgqstexp_osp_codehigh"
# [1139] "v2lgqstexp_osp_sd"               "v2lgqstexp_ord"
# [1141] "v2lgqstexp_ord_codelow"          "v2lgqstexp_ord_codehigh"
# [1143] "v2lgqstexp_mean"                 "v2lgqstexp_nr"
# [1145] "v2lginvstp"                      "v2lginvstp_codelow"
# [1147] "v2lginvstp_codehigh"             "v2lginvstp_sd"
# [1149] "v2lginvstp_osp"                  "v2lginvstp_osp_codelow"
# [1151] "v2lginvstp_osp_codehigh"         "v2lginvstp_osp_sd"
# [1153] "v2lginvstp_ord"                  "v2lginvstp_ord_codelow"
# [1155] "v2lginvstp_ord_codehigh"         "v2lginvstp_mean"
# [1157] "v2lginvstp_nr"                   "v2lgotovst"
# [1159] "v2lgotovst_codelow"              "v2lgotovst_codehigh"
# [1161] "v2lgotovst_sd"                   "v2lgotovst_osp"
# [1163] "v2lgotovst_osp_codelow"          "v2lgotovst_osp_codehigh"
# [1165] "v2lgotovst_osp_sd"               "v2lgotovst_ord"
# [1167] "v2lgotovst_ord_codelow"          "v2lgotovst_ord_codehigh"
# [1169] "v2lgotovst_mean"                 "v2lgotovst_nr"
# [1171] "v2lgcrrpt"                       "v2lgcrrpt_codelow"
# [1173] "v2lgcrrpt_codehigh"              "v2lgcrrpt_sd"
# [1175] "v2lgcrrpt_osp"                   "v2lgcrrpt_osp_codelow"
# [1177] "v2lgcrrpt_osp_codehigh"          "v2lgcrrpt_osp_sd"
# [1179] "v2lgcrrpt_ord"                   "v2lgcrrpt_ord_codelow"
# [1181] "v2lgcrrpt_ord_codehigh"          "v2lgcrrpt_mean"
# [1183] "v2lgcrrpt_nr"                    "v2lgoppart"
# [1185] "v2lgoppart_codelow"              "v2lgoppart_codehigh"
# [1187] "v2lgoppart_sd"                   "v2lgoppart_osp"
# [1189] "v2lgoppart_osp_codelow"          "v2lgoppart_osp_codehigh"
# [1191] "v2lgoppart_osp_sd"               "v2lgoppart_ord"
# [1193] "v2lgoppart_ord_codelow"          "v2lgoppart_ord_codehigh"
# [1195] "v2lgoppart_mean"                 "v2lgoppart_nr"
# [1197] "v2lgfunds"                       "v2lgfunds_codelow"
# [1199] "v2lgfunds_codehigh"              "v2lgfunds_sd"
# [1201] "v2lgfunds_osp"                   "v2lgfunds_osp_codelow"
# [1203] "v2lgfunds_osp_codehigh"          "v2lgfunds_osp_sd"
# [1205] "v2lgfunds_ord"                   "v2lgfunds_ord_codelow"
# [1207] "v2lgfunds_ord_codehigh"          "v2lgfunds_mean"
# [1209] "v2lgfunds_nr"                    "v2lgdsadlo"
# [1211] "v2lgdsadlo_codelow"              "v2lgdsadlo_codehigh"
# [1213] "v2lgdsadlo_sd"                   "v2lgdsadlo_osp"
# [1215] "v2lgdsadlo_osp_codelow"          "v2lgdsadlo_osp_codehigh"
# [1217] "v2lgdsadlo_osp_sd"               "v2lgdsadlo_ord"
# [1219] "v2lgdsadlo_ord_codelow"          "v2lgdsadlo_ord_codehigh"
# [1221] "v2lgdsadlo_mean"                 "v2lgdsadlo_nr"
# [1223] "v2lgdsadlobin"                   "v2lgdsadlobin_codelow"
# [1225] "v2lgdsadlobin_codehigh"          "v2lgdsadlobin_sd"
# [1227] "v2lgdsadlobin_osp"               "v2lgdsadlobin_osp_codelow"
# [1229] "v2lgdsadlobin_osp_codehigh"      "v2lgdsadlobin_osp_sd"
# [1231] "v2lgdsadlobin_ord"               "v2lgdsadlobin_ord_codelow"
# [1233] "v2lgdsadlobin_ord_codehigh"      "v2lgdsadlobin_mean"
# [1235] "v2lgdsadlobin_nr"                "v2lgtreaty"
# [1237] "v2lgwarlaw"                      "v2ex_legconhog"
# [1239] "v2ex_legconhos"                  "v2ex_hosw"
# [1241] "v2lgnameup"                      "v2lglegpup"
# [1243] "v2lglegpup_codelow"              "v2lglegpup_codehigh"
# [1245] "v2lglegpup_sd"                   "v2lglegpup_osp"
# [1247] "v2lglegpup_osp_codelow"          "v2lglegpup_osp_codehigh"
# [1249] "v2lglegpup_osp_sd"               "v2lglegpup_ord"
# [1251] "v2lglegpup_ord_codelow"          "v2lglegpup_ord_codehigh"
# [1253] "v2lglegpup_mean"                 "v2lglegpup_nr"
# [1255] "v2lgelecup"                      "v2lgintbup"
# [1257] "v2lginelup"                      "v2lgnamelo"
# [1259] "v2lglegplo"                      "v2lglegplo_codelow"
# [1261] "v2lglegplo_codehigh"             "v2lglegplo_sd"
# [1263] "v2lglegplo_osp"                  "v2lglegplo_osp_codelow"
# [1265] "v2lglegplo_osp_codehigh"         "v2lglegplo_osp_sd"
# [1267] "v2lglegplo_ord"                  "v2lglegplo_ord_codelow"
# [1269] "v2lglegplo_ord_codehigh"         "v2lglegplo_mean"
# [1271] "v2lglegplo_nr"                   "v2lgcomslo"
# [1273] "v2lgcomslo_codelow"              "v2lgcomslo_codehigh"
# [1275] "v2lgcomslo_sd"                   "v2lgcomslo_osp"
# [1277] "v2lgcomslo_osp_codelow"          "v2lgcomslo_osp_codehigh"
# [1279] "v2lgcomslo_osp_sd"               "v2lgcomslo_ord"
# ...
# [4183] "v2edteautonomy"                  "v2edteautonomy_codelow"
# [4185] "v2edteautonomy_codehigh"         "v2edteautonomy_sd"
# [4187] "v2edteautonomy_osp"              "v2edteautonomy_osp_codelow"
# [4189] "v2edteautonomy_osp_codehigh"     "v2edteautonomy_osp_sd"
# [4191] "v2edteautonomy_ord"              "v2edteautonomy_ord_codelow"
# [4193] "v2edteautonomy_ord_codehigh"     "v2edteautonomy_mean"
# [4195] "v2edteautonomy_nr"               "v2edmath"
# [4197] "v2edmath_codelow"                "v2edmath_codehigh"
# [4199] "v2edmath_sd"                     "v2edmath_osp"
# [4201] "v2edmath_osp_codelow"            "v2edmath_osp_codehigh"
# [4203] "v2edmath_osp_sd"                 "v2edmath_ord"
# [4205] "v2edmath_ord_codelow"            "v2edmath_ord_codehigh"
# [4207] "v2edmath_mean"                   "v2edmath_mode"
# [4209] "v2edmath_nr"                     "v2edideolch_1"
# [4211] "v2edideolch_2"                   "v2edideolch_3"
# [4213] "v2edideolch_4"                   "v2edideolch_5"
# [4215] "v2edideolch_6"                   "v2edideolch_7"
# [4217] "v2edideolch_8"                   "v2edideolch_9"
# [4219] "v2edideolch_10"                  "v2edideolch_nr"
# [4221] "v2medstateprint"                 "v2medstateprint_codelow"
# [4223] "v2medstateprint_codehigh"        "v2medstateprint_sd"
# [4225] "v2medstateprint_osp"             "v2medstateprint_osp_codelow"
# [4227] "v2medstateprint_osp_codehigh"    "v2medstateprint_osp_sd"
# [4229] "v2medstateprint_ord"             "v2medstateprint_ord_codelow"
# [4231] "v2medstateprint_ord_codehigh"    "v2medstateprint_mean"
# [4233] "v2medstateprint_nr"              "v2medstatebroad"
# [4235] "v2medstatebroad_codelow"         "v2medstatebroad_codehigh"
# [4237] "v2medstatebroad_sd"              "v2medstatebroad_osp"
# [4239] "v2medstatebroad_osp_codelow"     "v2medstatebroad_osp_codehigh"
# [4241] "v2medstatebroad_osp_sd"          "v2medstatebroad_ord"
# [4243] "v2medstatebroad_ord_codelow"     "v2medstatebroad_ord_codehigh"
# [4245] "v2medstatebroad_mean"            "v2medstatebroad_nr"
# [4247] "v2medpolstate"                   "v2medpolstate_codelow"
# [4249] "v2medpolstate_codehigh"          "v2medpolstate_sd"
# [4251] "v2medpolstate_osp"               "v2medpolstate_osp_codelow"
# [4253] "v2medpolstate_osp_codehigh"      "v2medpolstate_osp_sd"
# [4255] "v2medpolstate_ord"               "v2medpolstate_ord_codelow"
# [4257] "v2medpolstate_ord_codehigh"      "v2medpolstate_mean"
# [4259] "v2medpolstate_nr"                "v2medpolnonstate"
# [4261] "v2medpolnonstate_codelow"        "v2medpolnonstate_codehigh"
# [4263] "v2medpolnonstate_sd"             "v2medpolnonstate_osp"
# [4265] "v2medpolnonstate_osp_codelow"    "v2medpolnonstate_osp_codehigh"
# [4267] "v2medpolnonstate_osp_sd"         "v2medpolnonstate_ord"
# [4269] "v2medpolnonstate_ord_codelow"    "v2medpolnonstate_ord_codehigh"
# [4271] "v2medpolnonstate_mean"           "v2medpolnonstate_nr"
# [4273] "v2medpatriot"                    "v2medpatriot_codelow"
# [4275] "v2medpatriot_codehigh"           "v2medpatriot_sd"
# [4277] "v2medpatriot_osp"                "v2medpatriot_osp_codelow"
# [4279] "v2medpatriot_osp_codehigh"       "v2medpatriot_osp_sd"
# [4281] "v2medpatriot_ord"                "v2medpatriot_ord_codelow"
# [4283] "v2medpatriot_ord_codehigh"       "v2medpatriot_mean"
# [4285] "v2medpatriot_nr"                 "v2medentrain"
# [4287] "v2medentrain_codelow"            "v2medentrain_codehigh"
# [4289] "v2medentrain_sd"                 "v2medentrain_osp"
# [4291] "v2medentrain_osp_codelow"        "v2medentrain_osp_codehigh"
# [4293] "v2medentrain_osp_sd"             "v2medentrain_ord"
# [4295] "v2medentrain_ord_codelow"        "v2medentrain_ord_codehigh"
# [4297] "v2medentrain_mean"               "v2medentrain_nr"
# [4299] "v2edscpatriot"                   "v2edscpatriot_codelow"
# [4301] "v2edscpatriot_codehigh"          "v2edscpatriot_sd"
# [4303] "v2edscpatriot_osp"               "v2edscpatriot_osp_codelow"
# [4305] "v2edscpatriot_osp_codehigh"      "v2edscpatriot_osp_sd"
# [4307] "v2edscpatriot_ord"               "v2edscpatriot_ord_codelow"
# [4309] "v2edscpatriot_ord_codehigh"      "v2edscpatriot_mean"
# [4311] "v2edscpatriot_mode"              "v2edscpatriot_nr"
# [4313] "v2edscpatriotcb"                 "v2edscpatriotcb_codelow"
# [4315] "v2edscpatriotcb_codehigh"        "v2edscpatriotcb_sd"
# [4317] "v2edscpatriotcb_osp"             "v2edscpatriotcb_osp_codelow"
# [4319] "v2edscpatriotcb_osp_codehigh"    "v2edscpatriotcb_osp_sd"
# [4321] "v2edscpatriotcb_ord"             "v2edscpatriotcb_ord_codelow"
# [4323] "v2edscpatriotcb_ord_codehigh"    "v2edscpatriotcb_mean"
# [4325] "v2edscpatriotcb_nr"              "v2edscextracurr"
# [4327] "v2edscextracurr_codelow"         "v2edscextracurr_codehigh"
# [4329] "v2edscextracurr_sd"              "v2edscextracurr_osp"
# [4331] "v2edscextracurr_osp_codelow"     "v2edscextracurr_osp_codehigh"
# [4333] "v2edscextracurr_osp_sd"          "v2edscextracurr_ord"
# [4335] "v2edscextracurr_ord_codelow"     "v2edscextracurr_ord_codehigh"
# [4337] "v2edscextracurr_mean"            "v2edscextracurr_nr"
# [4339] "v2edtequal"                      "v2edtequal_codelow"
# [4341] "v2edtequal_codehigh"             "v2edtequal_sd"
# [4343] "v2edtequal_osp"                  "v2edtequal_osp_codelow"
# [4345] "v2edtequal_osp_codehigh"         "v2edtequal_osp_sd"
# [4347] "v2edtequal_ord"                  "v2edtequal_ord_codelow"
# [4349] "v2edtequal_ord_codehigh"         "v2edtequal_mean"
# [4351] "v2edtequal_nr"                   "v2temonitor"
# [4353] "v2temonitor_codelow"             "v2temonitor_codehigh"
# [4355] "v2temonitor_sd"                  "v2temonitor_osp"
# [4357] "v2temonitor_osp_codelow"         "v2temonitor_osp_codehigh"
# [4359] "v2temonitor_osp_sd"              "v2temonitor_ord"
# [4361] "v2temonitor_ord_codelow"         "v2temonitor_ord_codehigh"
# [4363] "v2temonitor_mean"                "v2temonitor_nr"
# [4365] "v2edteunion"                     "v2edteunion_codelow"
# [4367] "v2edteunion_codehigh"            "v2edteunion_sd"
# [4369] "v2edteunion_osp"                 "v2edteunion_osp_codelow"
# [4371] "v2edteunion_osp_codehigh"        "v2edteunion_osp_sd"
# [4373] "v2edteunion_ord"                 "v2edteunion_ord_codelow"
# [4375] "v2edteunion_ord_codehigh"        "v2edteunion_mean"
# [4377] "v2edteunion_mode"                "v2edteunion_nr"
# [4379] "v2edteunionindp"                 "v2edteunionindp_codelow"
# [4381] "v2edteunionindp_codehigh"        "v2edteunionindp_sd"
# [4383] "v2edteunionindp_osp"             "v2edteunionindp_osp_codelow"
# [4385] "v2edteunionindp_osp_codehigh"    "v2edteunionindp_osp_sd"
# [4387] "v2edteunionindp_ord"             "v2edteunionindp_ord_codelow"
# [4389] "v2edteunionindp_ord_codehigh"    "v2edteunionindp_mean"
# [4391] "v2edteunionindp_nr"              "v2edtehire"
# [4393] "v2edtehire_codelow"              "v2edtehire_codehigh"
# [4395] "v2edtehire_sd"                   "v2edtehire_osp"
# [4397] "v2edtehire_osp_codelow"          "v2edtehire_osp_codehigh"
# [4399] "v2edtehire_osp_sd"               "v2edtehire_ord"
# [4401] "v2edtehire_ord_codelow"          "v2edtehire_ord_codehigh"
# [4403] "v2edtehire_mean"                 "v2edtehire_nr"
# [4405] "v2edtefire"                      "v2edtefire_codelow"
# [4407] "v2edtefire_codehigh"             "v2edtefire_sd"
# [4409] "v2edtefire_osp"                  "v2edtefire_osp_codelow"
# [4411] "v2edtefire_osp_codehigh"         "v2edtefire_osp_sd"
# [4413] "v2edtefire_ord"                  "v2edtefire_ord_codelow"
# [4415] "v2edtefire_ord_codehigh"         "v2edtefire_mean"
# [4417] "v2edtefire_nr"                   "e_v2x_clpriv_3C"
# [4419] "e_v2x_clpriv_4C"                 "e_v2x_clpriv_5C"
# [4421] "e_v2xdl_delib_3C"                "e_v2xdl_delib_4C"
# [4423] "e_v2xdl_delib_5C"                "e_v2x_egaldem_3C"
# [4425] "e_v2x_egaldem_4C"                "e_v2x_egaldem_5C"
# [4427] "e_v2x_pubcorr_3C"                "e_v2x_pubcorr_4C"
# [4429] "e_v2x_pubcorr_5C"                "e_v2x_execorr_3C"
# [4431] "e_v2x_execorr_4C"                "e_v2x_execorr_5C"
# [4433] "e_v2x_egal_3C"                   "e_v2x_egal_4C"
# [4435] "e_v2x_egal_5C"                   "e_v2x_clphy_3C"
# [4437] "e_v2x_clphy_4C"                  "e_v2x_clphy_5C"
# [4439] "e_v2xdd_dd_3C"                   "e_v2xdd_dd_4C"
# [4441] "e_v2xdd_dd_5C"                   "e_v2xel_locelec_3C"
# [4443] "e_v2xel_locelec_4C"              "e_v2xel_locelec_5C"
# [4445] "e_v2x_suffr_3C"                  "e_v2x_suffr_4C"
# [4447] "e_v2x_suffr_5C"                  "e_v2x_freexp_altinf_3C"
# [4449] "e_v2x_freexp_altinf_4C"          "e_v2x_freexp_altinf_5C"
# [4451] "e_v2x_gencl_3C"                  "e_v2x_gencl_4C"
# [4453] "e_v2x_gencl_5C"                  "e_v2x_frassoc_thick_3C"
# [4455] "e_v2x_frassoc_thick_4C"          "e_v2x_frassoc_thick_5C"
# [4457] "e_v2xme_altinf_3C"               "e_v2xme_altinf_4C"
# [4459] "e_v2xme_altinf_5C"               "e_v2x_libdem_3C"
# [4461] "e_v2x_libdem_4C"                 "e_v2x_libdem_5C"
# [4463] "e_v2x_mpi_3C"                    "e_v2x_mpi_4C"
# [4465] "e_v2x_mpi_5C"                    "e_v2xlg_legcon_3C"
# [4467] "e_v2xlg_legcon_4C"               "e_v2xlg_legcon_5C"
# [4469] "e_v2x_elecoff_3C"                "e_v2x_elecoff_4C"
# [4471] "e_v2x_elecoff_5C"                "e_v2x_delibdem_3C"
# [4473] "e_v2x_delibdem_4C"               "e_v2x_delibdem_5C"
# [4475] "e_v2x_partipdem_3C"              "e_v2x_partipdem_4C"
# [4477] "e_v2x_partipdem_5C"              "e_v2xps_party_3C"
# [4479] "e_v2xps_party_4C"                "e_v2xps_party_5C"
# [4481] "e_v2x_gender_3C"                 "e_v2x_gender_4C"
# [4483] "e_v2x_gender_5C"                 "e_v2x_gencs_3C"
# [4485] "e_v2x_gencs_4C"                  "e_v2x_gencs_5C"
# [4487] "e_v2x_feduni_3C"                 "e_v2x_feduni_4C"
# [4489] "e_v2x_feduni_5C"                 "e_v2x_civlib_3C"
# [4491] "e_v2x_civlib_4C"                 "e_v2x_civlib_5C"
# [4493] "e_v2xcl_rol_3C"                  "e_v2xcl_rol_4C"
# [4495] "e_v2xcl_rol_5C"                  "e_v2xeg_eqdr_3C"
# [4497] "e_v2xeg_eqdr_4C"                 "e_v2xeg_eqdr_5C"
# [4499] "e_v2x_clpol_3C"                  "e_v2x_clpol_4C"
# [4501] "e_v2x_clpol_5C"                  "e_v2x_EDcomp_thick_3C"
# [4503] "e_v2x_EDcomp_thick_4C"           "e_v2x_EDcomp_thick_5C"
# [4505] "e_v2x_partip_3C"                 "e_v2x_partip_4C"
# [4507] "e_v2x_partip_5C"                 "e_v2x_liberal_3C"
# [4509] "e_v2x_liberal_4C"                "e_v2x_liberal_5C"
# [4511] "e_v2xeg_eqprotec_3C"             "e_v2xeg_eqprotec_4C"
# [4513] "e_v2xeg_eqprotec_5C"             "e_v2x_corr_3C"
# [4515] "e_v2x_corr_4C"                   "e_v2x_corr_5C"
# [4517] "e_v2x_genpp_3C"                  "e_v2x_genpp_4C"
# [4519] "e_v2x_genpp_5C"                  "e_v2x_jucon_3C"
# [4521] "e_v2x_jucon_4C"                  "e_v2x_jucon_5C"
# [4523] "e_v2x_api_3C"                    "e_v2x_api_4C"
# [4525] "e_v2x_api_5C"                    "e_v2xcs_ccsi_3C"
# [4527] "e_v2xcs_ccsi_4C"                 "e_v2xcs_ccsi_5C"
# [4529] "e_v2x_polyarchy_3C"              "e_v2x_polyarchy_4C"
# [4531] "e_v2x_polyarchy_5C"              "e_v2xel_frefair_3C"
# [4533] "e_v2xel_frefair_4C"              "e_v2xel_frefair_5C"
# [4535] "e_v2x_cspart_3C"                 "e_v2x_cspart_4C"
# [4537] "e_v2x_cspart_5C"                 "e_v2x_freexp_3C"
# [4539] "e_v2x_freexp_4C"                 "e_v2x_freexp_5C"
# [4541] "e_v2xel_regelec_3C"              "e_v2xel_regelec_4C"
# [4543] "e_v2xel_regelec_5C"              "e_democracy_trans"
# [4545] "e_boix_regime"                   "e_democracy_breakdowns"
# [4547] "e_democracy_omitteddata"         "e_fh_rol"
# [4549] "e_fh_cl"                         "e_fh_pr"
# [4551] "e_fh_status"                     "e_wbgi_cce"
# [4553] "e_wbgi_pve"                      "e_wbgi_rle"
# [4555] "e_wbgi_vae"                      "e_wbgi_rqe"
# [4557] "e_wbgi_gee"                      "e_lexical_index"
# [4559] "e_uds_median"                    "e_uds_mean"
# [4561] "e_uds_pct025"                    "e_uds_pct975"
# [4563] "e_legparty"                      "e_coups"
# [4565] "e_p_polity"                      "e_democ"
# [4567] "e_autoc"                         "e_polity2"
# [4569] "e_polcomp"                       "e_ti_cpi"
# [4571] "e_chga_demo"                     "e_bnr_dem"
# [4573] "e_vanhanen"                      "e_peaveduc"
# [4575] "e_peedgini"                      "e_area"
# [4577] "e_regiongeo"                     "e_regionpol"
# [4579] "e_regionpol_6C"                  "e_regionpol_7C"
# [4581] "e_miinflat"                      "e_cow_imports"
# [4583] "e_cow_exports"                   "e_gdp"
# [4585] "e_gdp_sd"                        "e_gdppc"
# [4587] "e_gdppc_sd"                      "e_pop"
# [4589] "e_pop_sd"                        "e_total_resources_income_pc"
# [4591] "e_total_oil_income_pc"           "e_total_fuel_income_pc"
# [4593] "e_radio_n"                       "e_pelifeex"
# [4595] "e_miferrat"                      "e_pematmor"
# [4597] "e_miurbpop"                      "e_mipopula"
# [4599] "e_miurbani"                      "e_pefeliex"
# [4601] "e_wb_pop"                        "e_pechmor"
# [4603] "e_miinteco"                      "e_civil_war"
# [4605] "e_miinterc"                      "e_pt_coup"
# [4607] "e_pt_coup_attempts"

# %%
us_democracy_2010_2025 <- vdem %>%
  filter(
    country_name == "United States of America",
    year >= 2010,
    year <= 2025
  ) %>%
  select(
    country_name,
    year,
    v2x_libdem,
    v2x_delibdem
  )

print(us_democracy_2010_2025)
# Out:
#                country_name year v2x_libdem v2x_delibdem
# 1  United States of America 2010      0.850        0.862
# 2  United States of America 2011      0.848        0.860
# 3  United States of America 2012      0.847        0.859
# 4  United States of America 2013      0.850        0.862
# 5  United States of America 2014      0.847        0.858
# 6  United States of America 2015      0.848        0.853
# 7  United States of America 2016      0.832        0.813
# 8  United States of America 2017      0.745        0.630
# 9  United States of America 2018      0.742        0.629
# 10 United States of America 2019      0.735        0.616
# 11 United States of America 2020      0.725        0.593
# 12 United States of America 2021      0.752        0.708
# 13 United States of America 2022      0.763        0.718
# 14 United States of America 2023      0.771        0.720
# 15 United States of America 2024      0.748        0.739
